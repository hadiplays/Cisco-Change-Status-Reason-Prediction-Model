# %% [markdown]
# # Change Status Reason Prediction Model

# %% [markdown]
# ## Explanatory Data Analysis

# %%
import pandas as pd

# Making data frame from excel file
original_dataframe = pd.read_excel("NCM-Change Management - Results - CISCO.xlsx")

# %%
# Keep rows that have Cisco Engineering as a Vendor
original_dataframe = original_dataframe[original_dataframe['Vendor Name'] == 'Cisco Engineering']

# Take a look at the data being worked with
original_dataframe.head()
# Out:
#             Change             Link  \
# 0  CRQ000011207332  CRQ000011207332
# 1  CRQ000009568701  CRQ000009568701
# 2  CRQ000011239694  CRQ000011239694
# 3  CRQ000011323252  CRQ000011323252
# 4  CRQ000011323650  CRQ000011323650
#
#                                       Change Summary  \
# 0  NA3RC Cleanup to push ISE authentication chang...
# 1  STD-GLB-NETW- SDWAN Branch Transformation - Ba...
# 2                    STD-GLB-NETW-Cable Installation
# 3           STD-GLB-NETW-Cable Installation -TXW-D17
# 4          STD-GLB-NETW-Cable Installation - VAW-363
#
#                         Change Summary Requirements Derived Change Category  \
# 0           AMRS-NEC-DN(L)MODIFY-Router-ILW-268-CTO           NA3RC Project
# 1                                               NaN                     NaN
# 2                                               NaN                 CABLING
# 3   AMRS-STD-DN(P)Cabling support-TXW-D17-GT&O(FNJ)                  SWITCH
# 4  AMRS-STD-DN(P)Cabling support-VAW-363 -GT&O(FNJ)                  SWITCH
#
#   Change Risk Level Change Class Change Status    Change Status Reason  \
# 0      Risk Level 3       Normal        Closed              Successful
# 1      Risk Level 2     Standard        Closed  Successful with Issues
# 2      Risk Level 2     Standard        Closed              Successful
# 3      Risk Level 2     Standard        Closed              Successful
# 4      Risk Level 2     Standard        Closed              Successful
#
#   Change Status Reason - Enriched  ...  \
# 0                      Successful  ...
# 1          Successful with Issues  ...
# 2                      Successful  ...
# 3                      Successful  ...
# 4                      Successful  ...
#
#                             Change Manager Hierarchy  \
# 0  MOYNIHAN/BESSANT/REILLY/KERRISON/WALKER/MCCARR...
# 1  MOYNIHAN/BESSANT/REILLY/KERRISON/WALKER/MCCARR...
# 2  MOYNIHAN/BESSANT/REILLY/KERRISON/WALKER/MCCARR...
# 3  MOYNIHAN/BESSANT/REILLY/KERRISON/WALKER/MCCARR...
# 4  MOYNIHAN/BESSANT/REILLY/KERRISON/WALKER/MCCARR...
#
#   Change Manager Level 5 Name Change Manager Level 4 Name  \
# 0      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 1             NEWELL, JOHN A.           MCCARREN, PATRICK
# 2      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 3      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 4      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
#
#   Change Manager Level 3 Name Change Manager Level 2 Name  \
# 0         KERRISON, ANTONY R.               REILLY, DAVID
# 1         KERRISON, ANTONY R.               REILLY, DAVID
# 2         KERRISON, ANTONY R.               REILLY, DAVID
# 3         KERRISON, ANTONY R.               REILLY, DAVID
# 4         KERRISON, ANTONY R.               REILLY, DAVID
#
#                                           ChangeLink  \
# 0  https://itsm-webapp.bankofamerica.com/arsys/se...
# 1  https://itsm-webapp.bankofamerica.com/arsys/se...
# 2  https://itsm-webapp.bankofamerica.com/arsys/se...
# 3  https://itsm-webapp.bankofamerica.com/arsys/se...
# 4  https://itsm-webapp.bankofamerica.com/arsys/se...
#
#                                          Change Link OusideRange   NCM  \
# 0  CRQ000011207332#https://itsm-webapp.bankofamer...       False  True
# 1  CRQ000009568701#https://itsm-webapp.bankofamer...       False  True
# 2  CRQ000011239694#https://itsm-webapp.bankofamer...       False  True
# 3  CRQ000011323252#https://itsm-webapp.bankofamer...       False  True
# 4  CRQ000011323650#https://itsm-webapp.bankofamer...       False  True
#
#    FailedChangeReport
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
#
# [5 rows x 63 columns]

# %%
# Examine all types of Change Status that can occur in a Network Change
original_dataframe['Change Status Reason - Enriched'].unique()
# Out:
# array(['Successful', 'Successful with Issues', 'Backed Out',
#        'unsuccessful', 'Caused Incident with Impact', 'Caused Incident',
#        'Unsuccessful'], dtype=object)

# %%
# As seen above, data has split 'unsuccessful' and 'Unsuccessful'
# Clearly manual error; must fix by replacing all of them to one syntax
original_dataframe.loc[ original_dataframe['Change Status Reason - Enriched'] == 'unsuccessful', 'Change Status Reason - Enriched'] = 'Unsuccessful'
# original_dataframe.loc[ original_dataframe['Change Status Reason - Enriched'] == 'Caused Incident with Impact', 'Change Status Reason - Enriched'] = 'Caused Incident'

# Check to see if change worked
original_dataframe['Change Status Reason - Enriched'].unique()
# Out:
# array(['Successful', 'Successful with Issues', 'Backed Out',
#        'Unsuccessful', 'Caused Incident with Impact', 'Caused Incident'],
#       dtype=object)

# %%
# Amount of rows in data frame
print("Amount of rows: " + str(len(original_dataframe.index)))
# Out:
# Amount of rows: 22316

# %%
# Get copy of original_dataframe
df = original_dataframe.copy()

# %%
# Check new df and if all dependent variables are there
df['Change Status Reason - Enriched'].unique()
# Out:
# array(['Successful', 'Successful with Issues', 'Backed Out',
#        'Unsuccessful', 'Caused Incident with Impact', 'Caused Incident'],
#       dtype=object)

# %%
# Graph the results

import matplotlib.pyplot as plt
import numpy as np

# Function to add value labels
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')

# Store all types of change status
change_status = df['Change Status Reason - Enriched'].unique()

# Create lists
xList = ['Successful', 
         'Successful w/ \nIssues', 
         'Backed Out',
         'Unsuccessful', 
         'Caused \nIncident \nw/ Impact', 
         'Caused \nIncident']
yList = []

# Add amounts to yList
for status in change_status:
    yList.append(df['Change Status Reason - Enriched'].value_counts()[status])

# Plot graph
plt.rcParams.update({'font.size': 12})

plt.figure(figsize = (10, 7)) # setting figure size by using figure() function
plt.bar(xList, yList) # simply having this line of code will generate the figure
plt.yscale('log') # set graph to logaraithmic y axis
addlabels(xList, yList) # calling the function to add value labels
plt.title("Change Status Reason") # set the title of the figure
plt.xlabel("Change Reason") # x-axis label
plt.ylabel("Amount") # y-axis label

plt.show() # display the figure

# %%
df = df[df['Change Status Reason - Enriched'] != 'Successful with Issues']
df = df[df['Change Status Reason - Enriched'] != 'Backed Out']

df['Change Status Reason - Enriched'].unique()
# Out:
# array(['Successful', 'Unsuccessful', 'Caused Incident with Impact',
#        'Caused Incident'], dtype=object)

# %% [markdown]
# ## Data Preprocessing

# %%
df[df.columns[df.isna().any()]]
# Out:
#                              Change Summary Requirements  \
# 0                AMRS-NEC-DN(L)MODIFY-Router-ILW-268-CTO
# 2                                                    NaN
# 3        AMRS-STD-DN(P)Cabling support-TXW-D17-GT&O(FNJ)
# 4       AMRS-STD-DN(P)Cabling support-VAW-363 -GT&O(FNJ)
# 5      AMRS-STD-DN(P)ADD-Rack & Stack data Equipment ...
# ...                                                  ...
# 36770         AMRS-NML-DN(L)CONFIGURE-Switch-MULTI-MULTI
# 36780                                                NaN
# 36782  AMRS-NML-DN(L)DECOMMISSION-Router-AZ1-806-MULT...
# 36784  AMRS-NML-DN(LP)CONFIGURE-Data Center Backbone ...
# 36785  AMRS-NML-DN(L)DECOMMISSION-Switch-AZ1-806-MULT...
#
#       Derived Change Category Failed Change Root Cause Incident Number  \
# 0               NA3RC Project                      NaN             NaN
# 2                     CABLING                      NaN             NaN
# 3                      SWITCH                      NaN             NaN
# 4                      SWITCH                      NaN             NaN
# 5                      SWITCH                      NaN             NaN
# ...                       ...                      ...             ...
# 36770                  SWITCH                      NaN             NaN
# 36780                  SWITCH                      NaN             NaN
# 36782                  ROUTER                      NaN             NaN
# 36784                  SWITCH                      NaN             NaN
# 36785                  SWITCH                      NaN             NaN
#
#       Incident Priority Change Sheduled for Approval Date  \
# 0                   NaN               2019-12-09 21:49:59
# 2                   NaN               2019-12-13 11:44:45
# 3                   NaN               2019-12-23 13:48:55
# 4                   NaN               2019-12-23 13:49:49
# 5                   NaN               2019-12-23 13:31:50
# ...                 ...                               ...
# 36770               NaN               2022-06-16 23:10:28
# 36780               NaN               2022-06-21 15:53:46
# 36782               NaN               2022-06-21 11:51:08
# 36784               NaN               2022-06-21 13:12:18
# 36785               NaN               2022-06-18 14:24:58
#
#       Change Operational Categorization Tier 1  \
# 0                                       MODIFY
# 2                                      INSTALL
# 3                                      INSTALL
# 4                                      INSTALL
# 5                                          ADD
# ...                                        ...
# 36770                                   BACKUP
# 36780                                      ADD
# 36782                             DECOMMISSION
# 36784                                CONFIGURE
# 36785                             DECOMMISSION
#
#       Change Operational Categorization Tier 2  \
# 0                                      NETWORK
# 2                                      NETWORK
# 3                                      NETWORK
# 4                                      NETWORK
# 5                                      NETWORK
# ...                                        ...
# 36770                                  NETWORK
# 36780                                  NETWORK
# 36782                                  NETWORK
# 36784                                  NETWORK
# 36785                                  NETWORK
#
#       Change Operational Categorization Tier 3 Change Product Category Tier 1  \
# 0                                         DATA         NETWORK INFRASTRUCTURE
# 2                                      CABLING                     COLLECTION
# 3                                      CABLING                     COLLECTION
# 4                                      CABLING                     COLLECTION
# 5                                     HARDWARE                     COLLECTION
# ...                                        ...                            ...
# 36770                                     PORT         NETWORK INFRASTRUCTURE
# 36780                                     PORT                     COLLECTION
# 36782                                INTERFACE         NETWORK INFRASTRUCTURE
# 36784                                   DEVICE         NETWORK INFRASTRUCTURE
# 36785                                   DEVICE         NETWORK INFRASTRUCTURE
#
#       Change Product Category Tier 2 Change Product Category Tier 3
# 0                            NETWORK                         ROUTER
# 2                         LOGICAL CI                     FACILITIES
# 3                         LOGICAL CI                     FACILITIES
# 4                         LOGICAL CI                     FACILITIES
# 5                         LOGICAL CI                     FACILITIES
# ...                              ...                            ...
# 36770                        NETWORK                         SWITCH
# 36780                     LOGICAL CI                     FACILITIES
# 36782                        NETWORK                         SWITCH
# 36784                        NETWORK                         SWITCH
# 36785                        NETWORK                         SWITCH
#
# [22002 rows x 12 columns]

# %%
# Drop columns with N/A values and that are not important/needed for our models
df = df.drop(['Change Summary Requirements', 'Failed Change Root Cause', 'Incident Number', 'Incident Priority'], axis=1)

# %%
# Fill in remaining columns who have N/A values with 'NaN'
df = df.fillna('NaN')

# %%
# Check isna()
df.isna().sum()

# Timestamp object is fine to have N/A values
# Out:
# Change                                       0
# Link                                         0
# Change Summary                               0
# Derived Change Category                      0
# Change Risk Level                            0
# Change Class                                 0
# Change Status                                0
# Change Status Reason                         0
# Change Status Reason - Enriched              0
# Vendor Name                                  0
# Change Sheduled for Approval Date           11
# Change Scheduled Start Dt                    0
# Change Scheduled Start Year                  0
# Change Scheduled Start Month                 0
# Change Scheduled End Dt                      0
# Change Scheduled End Year                    0
# Change Scheduled End Month                   0
# Change Actual Start Dt                       0
# Change Actual Start Year                     0
# Change Actual Start Month                    0
# Start Month Num                              0
# Start Month                                  0
# Start Week Num                               0
# Change Actual End Dt                         0
# Change Actual End Year                       0
# Change Actual End Month                      0
# End Month Num                                0
# End Month                                    0
# End Week Num                                 0
# Change Coordinator Name                      0
# Change Coordinator Email                     0
# Change Manager Name                          0
# Change Manager Email                         0
# Change Environment                           0
# Change Impact                                0
# Change Priority                              0
# Change Urgency                               0
# Change with Business Impact Flag             0
# Change Operational Categorization Tier 1     0
# Change Operational Categorization Tier 2     0
# Change Operational Categorization Tier 3     0
# Change Product Category Tier 1               0
# Change Product Category Tier 2               0
# Change Product Category Tier 3               0
# Change Manager Region                        0
# Change Manager Organization                  0
# Change Manager Department                    0
# Change Coordinator Group                     0
# Change Manager Group                         0
# Change Manager Hierarchy                     0
# Change Manager Level 5 Name                  0
# Change Manager Level 4 Name                  0
# Change Manager Level 3 Name                  0
# Change Manager Level 2 Name                  0
# ChangeLink                                   0
# Change Link                                  0
# OusideRange                                  0
# NCM                                          0
# FailedChangeReport                           0
# dtype: int64

# %%
# Calculate number of days network change was done in
from datetime import datetime
date_format = "%m/%d/%Y"

result =[]

for index, row in df.iterrows():
    a = row['Change Actual Start Dt']
    b = row['Change Actual End Dt']
    delta = b - a
    result.append(delta.days)

df['Days'] = result

# Add column to df after enumerating categorical values
df.head()
# Out:
#             Change             Link  \
# 0  CRQ000011207332  CRQ000011207332
# 2  CRQ000011239694  CRQ000011239694
# 3  CRQ000011323252  CRQ000011323252
# 4  CRQ000011323650  CRQ000011323650
# 5  CRQ000011323646  CRQ000011323646
#
#                                       Change Summary Derived Change Category  \
# 0  NA3RC Cleanup to push ISE authentication chang...           NA3RC Project
# 2                    STD-GLB-NETW-Cable Installation                 CABLING
# 3           STD-GLB-NETW-Cable Installation -TXW-D17                  SWITCH
# 4          STD-GLB-NETW-Cable Installation - VAW-363                  SWITCH
# 5            STD-GLB-NETW-RACKANDSTACK-ADD - VAW-363                  SWITCH
#
#   Change Risk Level Change Class Change Status Change Status Reason  \
# 0      Risk Level 3       Normal        Closed           Successful
# 2      Risk Level 2     Standard        Closed           Successful
# 3      Risk Level 2     Standard        Closed           Successful
# 4      Risk Level 2     Standard        Closed           Successful
# 5      Risk Level 2     Standard        Closed           Successful
#
#   Change Status Reason - Enriched        Vendor Name  ...  \
# 0                      Successful  Cisco Engineering  ...
# 2                      Successful  Cisco Engineering  ...
# 3                      Successful  Cisco Engineering  ...
# 4                      Successful  Cisco Engineering  ...
# 5                      Successful  Cisco Engineering  ...
#
#   Change Manager Level 5 Name Change Manager Level 4 Name  \
# 0      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 2      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 3      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 4      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
# 5      SISTO, NICOLA A.(NICK)           MCCARREN, PATRICK
#
#    Change Manager Level 3 Name Change Manager Level 2 Name  \
# 0          KERRISON, ANTONY R.               REILLY, DAVID
# 2          KERRISON, ANTONY R.               REILLY, DAVID
# 3          KERRISON, ANTONY R.               REILLY, DAVID
# 4          KERRISON, ANTONY R.               REILLY, DAVID
# 5          KERRISON, ANTONY R.               REILLY, DAVID
#
#                                           ChangeLink  \
# 0  https://itsm-webapp.bankofamerica.com/arsys/se...
# 2  https://itsm-webapp.bankofamerica.com/arsys/se...
# 3  https://itsm-webapp.bankofamerica.com/arsys/se...
# 4  https://itsm-webapp.bankofamerica.com/arsys/se...
# 5  https://itsm-webapp.bankofamerica.com/arsys/se...
#
#                                          Change Link OusideRange   NCM  \
# 0  CRQ000011207332#https://itsm-webapp.bankofamer...       False  True
# 2  CRQ000011239694#https://itsm-webapp.bankofamer...       False  True
# 3  CRQ000011323252#https://itsm-webapp.bankofamer...       False  True
# 4  CRQ000011323650#https://itsm-webapp.bankofamer...       False  True
# 5  CRQ000011323646#https://itsm-webapp.bankofamer...       False  True
#
#    FailedChangeReport Days
# 0                True   25
# 2                True   10
# 3                True    6
# 4                True    6
# 5                True    6
#
# [5 rows x 60 columns]

# %%
# Remove columns which should obviously not be used for model training/testing
df = df.drop(['Change', 
              'Link', 
              'Change Summary', 
              'Change Status Reason', 
              'Vendor Name', 
              'Change with Business Impact Flag', 
              'Change Manager Hierarchy'], axis = 1)

# %%
# Enumerate the following columns in order for the models to take values as input
df['Change Impact'] = df['Change Impact'].str.extract('(\d+)').astype(int)
df['Change Risk Level'] = df['Change Risk Level'].str.extract('(\d+)').astype(int)
df['Change Urgency'] = df['Change Urgency'].str.extract('(\d+)').astype(int)


# Every other variable is categorical
# We need to encode them so that our models can take its values as input
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for column in df:
    le.fit(df[column])
    df[column] = le.transform(df[column])
    
# Print all unique change status reasons
df['Change Status Reason - Enriched'].unique()
# Out:
# array([2, 3, 1, 0])

# %%
# Examine dataframe
df.head()
# Out:
#    Derived Change Category  Change Risk Level  Change Class  Change Status  \
# 0                       12                  2             2              0
# 2                        1                  1             3              0
# 3                       17                  1             3              0
# 4                       17                  1             3              0
# 5                       17                  1             3              0
#
#    Change Status Reason - Enriched  Change Sheduled for Approval Date  \
# 0                                2                                  9
# 2                                2                                 17
# 3                                2                                 69
# 4                                2                                 70
# 5                                2                                 66
#
#    Change Scheduled Start Dt  Change Scheduled Start Year  \
# 0                          0                            0
# 2                          1                            0
# 3                          2                            0
# 4                          2                            0
# 5                          2                            0
#
#    Change Scheduled Start Month  Change Scheduled End Dt  ...  \
# 0                             2                       41  ...
# 2                             2                        2  ...
# 3                             2                        0  ...
# 4                             2                        0  ...
# 5                             2                        0  ...
#
#    Change Manager Level 5 Name  Change Manager Level 4 Name  \
# 0                           19                           12
# 2                           19                           12
# 3                           19                           12
# 4                           19                           12
# 5                           19                           12
#
#    Change Manager Level 3 Name  Change Manager Level 2 Name  ChangeLink  \
# 0                            4                            4         683
# 2                            4                            4         711
# 3                            4                            4         844
# 4                            4                            4         856
# 5                            4                            4         833
#
#    Change Link  OusideRange  NCM  FailedChangeReport  Days
# 0          687            0    1                   0    25
# 2          697            0    1                   0    10
# 3          839            0    1                   0     6
# 4          843            0    1                   0     6
# 5          842            0    1                   0     6
#
# [5 rows x 53 columns]

# %%
# Examine columns which are producing errors when using SelectKBest function
# df.iloc[:, [12, 40, 61]]

# %%
# Target (Dependent) and Data (Independent) Values
target = df['Change Status Reason - Enriched']
data = df.drop(['Change Status Reason - Enriched', 'FailedChangeReport', 'NCM'], axis=1)

# %%
# We drop 'Change with Business Impact Flag', 'FailedChangeReport', and 'Vendor Name' in the data df because:
# - Will not benefit the models
# - Generates these warnings:
#     UserWarning: Features [12 40 61] are constant.
#         warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
#     RuntimeWarning: divide by zero encountered in divide
#         f = msb / msw 
#     RuntimeWarning: invalid value encountered in divide
#         f = msb / msw

# %%
# Feature selection to see which independent variables are best to use
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import VarianceThreshold

bestfeatures = SelectKBest(k='all')
fit = bestfeatures.fit(data, target)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(data.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score']
print(featureScores.nlargest(20,'Score'))
# Out:
#                                      Feature      Score
# 1                          Change Risk Level  69.725895
# 2                               Change Class  55.505472
# 30                            Change Urgency  29.107192
# 49                                      Days  28.959480
# 29                           Change Priority  28.019887
# 31  Change Operational Categorization Tier 1  27.402168
# 28                             Change Impact  25.528219
# 37                     Change Manager Region   8.940054
# 34            Change Product Category Tier 1   7.933568
# 44               Change Manager Level 3 Name   7.636699
# 36            Change Product Category Tier 3   6.425455
# 45               Change Manager Level 2 Name   6.155682
# 43               Change Manager Level 4 Name   6.057800
# 26                      Change Manager Email   5.555341
# 42               Change Manager Level 5 Name   4.976420
# 47                               Change Link   4.520085
# 46                                ChangeLink   4.512473
# 17                      Change Actual End Dt   4.418522
# 8                    Change Scheduled End Dt   4.412029
# 4          Change Sheduled for Approval Date   4.117526

# %%
# Take a random sample of the successfuls so that machine doesn't over predict successful
successful_df = df[df["Change Status Reason - Enriched"]==2]
successful_df = successful_df.sample(n = 600, random_state=79312830)
len(successful_df.index)

not_successful_df = df[df["Change Status Reason - Enriched"]!=2]
len(not_successful_df.index)

# Concatinate dataframe from the two filtered dataframe
frames = [successful_df, not_successful_df]
df = pd.concat(frames)

# Amount of rows in new data frame
len(df.index)
# Out:
# 864

# %%
# New target and data values
target = df['Change Status Reason - Enriched']
data = df.drop('Change Status Reason - Enriched', axis=1)

# %%
# Include top ten features that will be used based on SelectKBest function
features_list_df = data
# [["Change Risk Level", "Change Class", "Change Impact", "Change Urgency", "Days", "Change Priority", "Change Operational Categorization Tier 1"]]
                         #, "Change Product Category Tier 3", "Change Product Category Tier 1"]]
#, "Change Manager Region", "Derived Change Category"


# Reason 'Failed Change Root Cause' is not included is because this would defeat
# the purpose of the prediction model, as this is what occurs after a network change
# has been made. Model is used to predict outcome of the network change prior to 
# a failure occurs, hence root cause should not be accounted for.
# 'Change Status Reason' also removed because it would be giving the model the dependent
# variable needed to make a decision

# %%
# Independent and dependent variables to numpy array 
X = features_list_df.to_numpy()
y = target.to_numpy()

# %% [markdown]
# ## Classification Modeling

# %%
# Split train and test data
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler

# scale = StandardScaler()
# scaled_X = scale.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Amount of train and test data
print (X_train.shape, y_train.shape)
print (X_test.shape, y_test.shape)
# Out:
# (648, 52) (648,)
# (216, 52) (216,)

# %%
# Amount for each change status reason being trained
from collections import Counter

print('Original train dataset shape %s' % Counter(y_train))
# Out:
# Original train dataset shape Counter({2: 452, 0: 123, 3: 46, 1: 27})

# %%
# Use SMOTE for oversampling issues in the data
from imblearn.over_sampling import SMOTE

# SMOTE: Synthetic Minority Oversampling Technique Model
sm = SMOTE(random_state=21)
X_sm, y_sm = sm.fit_resample(X_train, y_train)
print('Resampled SMOTE train dataset shape %s' % Counter(y_sm))
print (X_sm.shape, y_sm.shape)
# Out:
# Resampled SMOTE train dataset shape Counter({2: 452, 0: 452, 1: 452, 3: 452})
# (1808, 52) (1808,)

# %%
# Import classifiers and metrics from sklearn
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix, roc_curve, auc, classification_report

# %%
# Initialize the models
neigh = KNeighborsClassifier(n_neighbors=3)
svc = SVC(probability=True)
nbc = GaussianNB()
rfc = RandomForestClassifier()

# Train ML model with training dataset using model.fit() function
neigh.fit(X_sm, y_sm)
svc.fit(X_sm, y_sm)
nbc.fit(X_sm, y_sm)
rfc.fit(X_sm, y_sm)
# Out:
# RandomForestClassifier()

# %%
# Training complete, test your model with testing dataset

y_knn_predicted = neigh.predict(X_test)
y_knn_pred_proba = neigh.predict_proba(X_test)

y_svc_predicted = svc.predict(X_test)
y_svc_pred_proba = svc.predict_proba(X_test)

y_nbc_predicted = nbc.predict(X_test)
y_nbc_pred_proba = nbc.predict_proba(X_test)

y_rfc_predicted = rfc.predict(X_test)
y_rfc_pred_proba = rfc.predict_proba(X_test)

# %%
# Create confussion matrices for each model
print(classification_report(y_test, y_knn_predicted))
print(classification_report(y_test, y_svc_predicted))
print(classification_report(y_test, y_nbc_predicted))
print(classification_report(y_test, y_rfc_predicted))

models = ['K Nearest Neighbor', 'Support Vector Machine', 'Naive Bayes Classifier', 'Random Forest Classifier']
predictions = [y_knn_predicted, y_svc_predicted, y_nbc_predicted, y_rfc_predicted]
pred_probabilities = [y_knn_pred_proba, y_svc_pred_proba, y_nbc_pred_proba, y_rfc_pred_proba]

plot = 1

for model, prediction, pred_proba in zip(models, predictions, pred_probabilities):
    disp = ConfusionMatrixDisplay(confusion_matrix(y_test.ravel(), prediction))
    disp.plot(
        include_values=True,
        cmap='gray',
        colorbar=False
    )
    disp.ax_.set_title(f"{model} Confusion Matrix")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.25      0.31      0.27        49
#            1       0.07      0.25      0.11         8
#            2       0.72      0.42      0.53       148
#            3       0.07      0.27      0.12        11
#
#     accuracy                           0.38       216
#    macro avg       0.28      0.31      0.26       216
# weighted avg       0.56      0.38      0.43       216
#
#               precision    recall  f1-score   support
#
#            0       0.29      0.10      0.15        49
#            1       0.04      0.25      0.06         8
#            2       0.75      0.32      0.45       148
#            3       0.08      0.55      0.13        11
#
#     accuracy                           0.28       216
#    macro avg       0.29      0.31      0.20       216
# weighted avg       0.59      0.28      0.35       216
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.37      0.39        49
#            1       0.09      0.38      0.15         8
#            2       0.89      0.63      0.74       148
#            3       0.11      0.36      0.17        11
#
#     accuracy                           0.55       216
#    macro avg       0.38      0.43      0.36       216
# weighted avg       0.72      0.55      0.61       216
#
#               precision    recall  f1-score   support
#
#            0       0.42      0.27      0.33        49
#            1       0.00      0.00      0.00         8
#            2       0.77      0.84      0.80       148
#            3       0.13      0.18      0.15        11
#
#     accuracy                           0.64       216
#    macro avg       0.33      0.32      0.32       216
# weighted avg       0.63      0.64      0.63       216

# %%
# Get feature importances from the trained model
importances = rfc.feature_importances_

import matplotlib.pyplot as plt

# Create a DataFrame to store the feature importances with corresponding feature names
feature_importances_df = pd.DataFrame({'Feature': features_list_df.columns, 'Importance': importances})

# Sort the DataFrame in descending order based on feature importances
feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)

# Select only the top 10 features
top_15_features = feature_importances_df.head(15)[::-1]

# Create a horizontal bar plot to visualize the top 10 feature importances
plt.figure(figsize=(10, 6))
plt.barh(top_15_features['Feature'], top_15_features['Importance'])
plt.xlabel('Importance')
plt.ylabel('Features')
plt.title('Top 15 Feature Importances')
plt.tight_layout()  # Adjust the layout to prevent overlapping labels
plt.show()

# %%
# # Test RFC parameters
# param_grid = {
#     'n_estimators': [25, 50, 100, 150],
#     'max_features': ['sqrt', 'log2', None],
#     'max_depth': [3, 6, 9],
#     'max_leaf_nodes': [3, 6, 9],
# }

# from sklearn.model_selection import GridSearchCV,\
# RandomizedSearchCV

# grid_search = GridSearchCV(rfc, param_grid=param_grid)
# grid_search.fit(X_train, y_train)
# print(grid_search.best_estimator_)

# %%
# # Assuming you have a trained RFC model called 'rfc_model'
# # Assuming you have a dataframe called 'X_train' containing the training data

# # Get the feature importances from the RFC model
# importances = rfc.feature_importances_

# # Get the names of the features (columns)
# feature_names = data.to_numpy()  # Replace with your actual feature names

# # Create a dictionary to store the top features for each class
# top_features_by_class = {i: [] for i in range(len(rfc.classes_))}

# # Find the top features for each class
# for class_idx in range(len(rfc.classes_)):
#     # Filter the importances relevant to the current class
#     class_importances = importances[class_idx::len(rfc.classes_)]

#     # Sort the indices based on importance scores
#     sorted_indices = sorted(range(len(class_importances)), key=lambda k: class_importances[k], reverse=True)

#     # Get the top features and their corresponding importance scores
#     top_features = [(feature_names[idx], class_importances[idx]) for idx in sorted_indices]

#     # Store the top features for the current class
#     top_features_by_class[class_idx] = top_features

# # Print or visualize the top features for each class
# for class_idx, top_features in top_features_by_class.items():
#     class_label = rfc.classes_[class_idx]
#     print(f"Top variables for class '{class_label}':")
#     for feature, importance in top_features:
#         print(f"{feature}: {importance}")

# %%
# import matplotlib.pyplot as plt

# # Get feature importances for each class
# importances_per_class = rfc_classifier.feature_importances_

# # Get unique class labels
# unique_classes = np.unique(y_train)

# # Visualize the feature importances for each class (top 10 features)
# plt.figure(figsize=(10, 6))
# for class_label, importance_scores in zip(unique_classes, importances_per_class):
#     # Create a DataFrame for each class with corresponding feature names
#     feature_importances_df = pd.DataFrame({'Feature': features_list_df.columns, 'Importance': importance_scores})
    
#     # Sort the DataFrame in descending order based on feature importances
#     feature_importances_df = feature_importances_df.sort_values(by='Importance', ascending=False)
    
#     # Select only the top 10 features
#     top_10_features = feature_importances_df.head(10)

#     plt.barh(top_10_features['Feature'], top_10_features['Importance'], label=f'Class {class_label}')

# plt.xlabel('Importance')
# plt.ylabel('Features')
# plt.title('Top 10 Feature Importances for Each Class')
# plt.legend()
# plt.tight_layout()
# plt.show()

# %%
# # Get feature importances for each class
# importances_per_class = rfc.feature_importances_
# importances_per_class = importances_per_class.T


# # Create a DataFrame to store the feature importances with corresponding feature names
# feature_importances_df = pd.DataFrame(importances_per_class, columns=features_list_df.columns)

# # Transpose the DataFrame to have each row represent a feature and each column represent a class
# feature_importances_df = feature_importances_df.T

# # Visualize the feature importances for each class (top 10 features)
# plt.figure(figsize=(10, 6))
# for class_label in feature_importances_df.index:
#     top_10_features = feature_importances_df.loc[class_label].nlargest(10)
#     plt.barh(top_10_features.index, top_10_features.values, label=f'Class {class_label}')

# plt.xlabel('Importance')
# plt.ylabel('Features')
# plt.title('Top 10 Feature Importances for Each Class')
# plt.legend()
# plt.tight_layout()
# plt.show()
